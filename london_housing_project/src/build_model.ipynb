# %%
import pathlib
import duckdb
import geopandas as gpd
import pandas as pd

# %%
import pathlib

# In a notebook, use Path.cwd() instead of __file__
project_root = pathlib.Path.cwd().parent
db_path = project_root / "property_data.duckdb"
csv_path_housing = project_root / "data" / "pp-2026.csv"
csv_path_station = project_root / "data" / "stations.csv"


print(f"Project root: {project_root}")
print(f"Connecting to database at: {db_path}")

con = duckdb.connect(str(db_path))
# Out:
# Project root: c:\Users\alast\Documents\projects\london_housing_project
# Connecting to database at: c:\Users\alast\Documents\projects\london_housing_project\property_data.duckdb

# %%
con.execute(f"""
    DROP TABLE IF EXISTS raw_land_registry;
    CREATE OR REPLACE TABLE raw_land_registry AS 
    SELECT * FROM read_csv_auto(
        '{csv_path_housing}',
        header=False
    );
""")

# %%
con.execute(f"""
    DROP TABLE IF EXISTS raw_tfl_stations;
    CREATE OR REPLACE TABLE raw_tfl_stations AS
    SELECT * FROM read_csv_auto(
        '{csv_path_station}'
    );
""")

# %%
df = con.execute("""
SELECT * FROM raw_land_registry LIMIT 100;
""").fetchdf()

# %%
df
# Out:
#                                   column00  column01   column02  column03  \
# 0   {5340B1C6-37BD-8052-E063-4804A8C06EE4}    255777 2026-04-30   NE6 5HX
# 1   {5340B1C6-37C0-8052-E063-4804A8C06EE4}    155000 2026-04-20   NE6 5NS
# 2   {5340B1C6-37C1-8052-E063-4804A8C06EE4}    300000 2026-02-24   DH3 2SP
# 3   {5340B1C6-37C2-8052-E063-4804A8C06EE4}    430000 2026-04-30   NE2 2NA
# 4   {5340B1C6-37C5-8052-E063-4804A8C06EE4}     87500 2026-04-29   SR5 2EH
# ..                                     ...       ...        ...       ...
# 95  {5340B1C6-3F23-8052-E063-4804A8C06EE4}     54000 2026-04-21   BD6 1QL
# 96  {5340B1C6-3F29-8052-E063-4804A8C06EE4}     65000 2026-03-27  WF10 4PP
# 97  {5340B1C6-3F2A-8052-E063-4804A8C06EE4}    225000 2026-04-20  BD20 6RG
# 98  {5340B1C6-3F2B-8052-E063-4804A8C06EE4}    110000 2026-04-27  LS12 6JA
# 99  {5340B1C6-37F8-8052-E063-4804A8C06EE4}    290000 2026-04-28  NE28 7QA
#
#    column04 column05 column06   column07 column08           column09 column10  \
# 0         T        N        F         12     None   MUNDELLA TERRACE     None
# 1         F        N        L          4     None      FALMOUTH ROAD     None
# 2         O        N        F  RYDER PLC     None          FELL BANK  BIRTLEY
# 3         O        N        F        142     None   MANOR HOUSE ROAD     None
# 4         T        N        F         27     None  FLORENCE CRESCENT     None
# ..      ...      ...      ...        ...      ...                ...      ...
# 95        S        N        F         68     None          FAIR ROAD     None
# 96        F        N        L         21     None    LAGENTIUM PLAZA     None
# 97        S        N        F          4     None          INGS ROAD  STEETON
# 98        F        N        L         12     None        STEEL GREEN     None
# 99        O        N        F         26     None        THE MEADOWS     None
#
#                column11             column12        column13 column14 column15
# 0   NEWCASTLE UPON TYNE  NEWCASTLE UPON TYNE   TYNE AND WEAR        B        A
# 1   NEWCASTLE UPON TYNE  NEWCASTLE UPON TYNE   TYNE AND WEAR        B        A
# 2     CHESTER LE STREET            GATESHEAD   TYNE AND WEAR        B        A
# 3   NEWCASTLE UPON TYNE  NEWCASTLE UPON TYNE   TYNE AND WEAR        B        A
# 4            SUNDERLAND           SUNDERLAND   TYNE AND WEAR        B        A
# ..                  ...                  ...             ...      ...      ...
# 95             BRADFORD             BRADFORD  WEST YORKSHIRE        B        A
# 96           CASTLEFORD            WAKEFIELD  WEST YORKSHIRE        B        A
# 97             KEIGHLEY             BRADFORD  WEST YORKSHIRE        B        A
# 98                LEEDS                LEEDS  WEST YORKSHIRE        B        A
# 99             WALLSEND       NORTH TYNESIDE   TYNE AND WEAR        B        A
#
# [100 rows x 16 columns]
